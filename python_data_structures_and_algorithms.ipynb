# %% [markdown]
# <a href="https://colab.research.google.com/github/yibesh/-2025_Artifical-Intelligence-/blob/main/python_data_structures_and_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Practice: Data Structures and Algorithms
# This notebook covers basic Python data structures and simple algorithm examples for beginners.

# %%
# -------------------------------------------
# Python Practice: Data Structures and Algorithms
# -------------------------------------------

# 1️⃣ Basic Lists
numbers = [10, 5, 8, 20, 15]
print("Original list:", numbers)

numbers.append(25)
numbers.remove(8)
numbers.sort()
print("Modified list:", numbers)
# Out:
# Original list: [10, 5, 8, 20, 15]
# Modified list: [5, 10, 15, 20, 25]

# %%
# 2️⃣ Tuples (Immutable Lists)
coords = (5, 10)
print("\nTuple:", coords)
print("Access element:", coords[0])
# Out:
# Tuple: (5, 10)
# Access element: 5

# %%
# 3️⃣ Sets (No duplicates)
fruits = {"apple", "banana", "apple", "orange"}
print("\nSet:", fruits)
# Out:
# Set: {'orange', 'banana', 'apple'}

# %%
# 4️⃣ Dictionaries (Key-Value Pairs)
student = {"name": "Alice", "age": 21, "grade": "A"}
print("\nStudent dictionary:", student)
student["age"] = 22
print("Updated student age:", student["age"])
# Out:
# Student dictionary: {'name': 'Alice', 'age': 21, 'grade': 'A'}
# Updated student age: 22

# %%
# 5️⃣ Stack (LIFO)
stack = []
stack.append("A")
stack.append("B")
stack.append("C")
print("\nStack:", stack)
stack.pop()
print("After popping:", stack)
# Out:
# Stack: ['A', 'B', 'C']
# After popping: ['A', 'B']

# %%
# 6️⃣ Queue (FIFO)
from collections import deque
queue = deque(["A", "B", "C"])
print("\nQueue:", queue)
queue.popleft()
print("After dequeuing:", queue)
# Out:
# Queue: deque(['A', 'B', 'C'])
# After dequeuing: deque(['B', 'C'])
